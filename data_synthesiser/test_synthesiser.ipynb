# %% [markdown]
# Tests of the functions in the `data_synthesiser` module.

# %%
from data_synthesiser import *
import matplotlib.pyplot as plt

# %%
im = make_background_fuzzy(100, 100)
plt.imshow(im, cmap = 'gray', interpolation='none')
plt.show()

# %%
im = rotate_fuzz_and_crop(make_A_glyph())
plt.imshow(im, cmap='gray', interpolation='none')
plt.show()

# %%
im, lab = make_fuzzy_image_and_label()
plt.figure()
plt.imshow(im, cmap='gray', interpolation='none')
plt.figure()
plt.imshow(lab, cmap='gray', interpolation='none')
plt.show()
